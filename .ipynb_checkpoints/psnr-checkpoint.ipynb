# %%
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.autograd import Variable
import pickle 
from ply import write_ply

from scipy.special import sph_harm

from utilities import *
from VoxelGrid import VoxelGrid, VoxelGridSpherical, VoxelGridSphericalInterp
import os


from skimage.metrics import peak_signal_noise_ratio

os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
device='cuda' if torch.cuda.is_available() else 'cpu'

N_points=200

dataset = "../lego"

# %%
test_focal, test_c2w, test_gt = get_data(dataset, "test")
# Out:
# LOAD DATA ../lego/test
# 100%|█████████████████████████████████████████| 200/200 [00:04<00:00, 45.67it/s]

# %%
red = 4
disp_ims_test, disp_rays_test = reduce_data(test_c2w, test_gt,test_focal, red)
disp_im_w = disp_ims_test[0].shape[0]

# %%
VG = VoxelGrid(2)

# %%
def compute_psnr(grid, disp_rays_test, disp_ims_test, N_points=500):
    m = np.zeros(len(disp_ims_test))
    for i in range(len(disp_ims_test)):
        with torch.no_grad():
            new_im = grid.render_large_image_from_rays(disp_rays_test[i], (N_points, 1.2))

            m[i] = peak_signal_noise_ratio(new_im, disp_ims_test[i].astype('float32'))
    return m.mean()

# %%
psnr2 = []
for i in tqdm(range(0,33,2)):
    VG.load('16a_'+str(i)+'.obj')
    psnr2.append(compute_psnr(VG, disp_rays_test, disp_ims_test))
# Out:
# 100%|███████████████████████████████████████████| 17/17 [13:37<00:00, 48.10s/it]

# %%
plt.plot(psnr)

# %%
plt.imshow(disp_ims_test[0])

# %%
new_im = VG.render_large_image_from_rays(disp_rays_test[0], (200, 1.2))

# %%
plt.imshow(new_im)

# %%
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.autograd import Variable
import pickle 
from ply import write_ply

from scipy.special import sph_harm

from utilities import *
from VoxelGrid import VoxelGrid, VoxelGridSpherical, VoxelGridSphericalInterp
import os


from skimage.metrics import peak_signal_noise_ratio

os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
device='cuda' if torch.cuda.is_available() else 'cpu'

N_points=200

# %%
directories = [e for e in os.listdir("../nerf_synthetic") if os.path.isdir("../nerf_synthetic/"+e)]

# %%
def compute_psnr(grid, disp_rays_test, disp_ims_test, N_points=500):
    m = np.zeros(len(disp_ims_test))
    for i in tqdm(range(len(disp_ims_test))):
        with torch.no_grad():
            new_im = grid.render_large_image_from_rays(disp_rays_test[i], (N_points, 1.2))

            m[i] = peak_signal_noise_ratio(new_im, disp_ims_test[i].astype('float32'))
    return m.mean()

# %%
for nerf_dir in directories:
    VG = VoxelGrid()
    VG.load(nerf_dir+".obj")
    test_focal, test_c2w, test_gt = get_data("../nerf_synthetic/"+nerf_dir, "test")
    red = 8
    disp_ims_test, disp_rays_test = reduce_data(test_c2w, test_gt,test_focal, red)
    disp_im_w = disp_ims_test[0].shape[0]
    print(nerf_dir, compute_psnr(VG, disp_rays_test, disp_ims_test))
# Out:
# LOAD DATA ../nerf_synthetic/materials/test
# ...
# 100%|█████████████████████████████████████████| 200/200 [00:06<00:00, 32.82it/s]
# materials 20.9423073944661
# LOAD DATA ../nerf_synthetic/drums/test
# ...
# 100%|█████████████████████████████████████████| 200/200 [00:05<00:00, 34.23it/s]
# drums 20.13933661924704
# LOAD DATA ../nerf_synthetic/chair/test
# ...
# 100%|█████████████████████████████████████████| 200/200 [00:05<00:00, 34.20it/s]
# chair 23.32745291071876
# LOAD DATA ../nerf_synthetic/mic/test
# ...
# 100%|█████████████████████████████████████████| 200/200 [00:05<00:00, 33.72it/s]
# mic 22.3932078080264
# LOAD DATA ../nerf_synthetic/hotdog/test
# ...
# 100%|█████████████████████████████████████████| 200/200 [00:05<00:00, 34.40it/s]
# hotdog 23.40257019038042
# LOAD DATA ../nerf_synthetic/lego/test
# ...
# 100%|█████████████████████████████████████████| 200/200 [00:05<00:00, 34.33it/s]
# lego 21.626002357471645
# LOAD DATA ../nerf_synthetic/ficus/test
# ...

# %%
L = """materials 20.9423073944661
drums 20.13933661924704
chair 23.32745291071876
mic 22.3932078080264
hotdog 23.40257019038042
lego 21.626002357471645
ficus 23.909211383752435
ship 20.63517583722394"""

# %%
np.array([float(e) for e in L.split()[1::2]]).std()
# Out:
# 1.3273485329177772

# %%
VG = VoxelGrid()
VG.load("out_grid.obj")
dataset  = "hotdog"

# %%
test_focal, test_c2w, test_gt = get_data("../nerf_synthetic/"+dataset, "test")
# Out:
# LOAD DATA ../nerf_synthetic/hotdog/test
# 100%|█████████████████████████████████████████| 200/200 [00:03<00:00, 59.14it/s]

# %%
red = 8
disp_ims_test, disp_rays_test = reduce_data(test_c2w, test_gt,test_focal, red)
disp_im_w = disp_ims_test[0].shape[0]

# %%
compute_psnr(VG, disp_rays_test, disp_ims_test)
# Out:
# 100%|█████████████████████████████████████████| 200/200 [00:05<00:00, 34.28it/s]
# 23.401842994694345

# %%
plt.imshow(disp_ims_test[2])

# %%
VG.load('out_grid.obj')

# %%
plt.imshow(VG.render_large_image_from_rays(disp_rays_test[2], (1000, 1.2)))

# %%
psnr2 = []
for i in tqdm(range(0,33,2)):
    VG.load('16a_'+str(i)+'.obj')
    psnr2.append(compute_psnr(VG, disp_rays_test, disp_ims_test))
# Out:
# ...
#  12%|█████▏                                      | 2/17 [00:32<04:04, 16.31s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_21996/4214542973.py in <module>
#       2 for i in tqdm(range(0,33,2)):
#       3     VG.load('16a_'+str(i)+'.obj')
# ----> 4     psnr2.append(compute_psnr(VG, disp_rays_test, disp_ims_test))
#
# /tmp/ipykernel_21996/2510728883.py in compute_psnr(grid, disp_rays_test, disp_ims_test, N_points)
#       3     for i in tqdm(range(len(disp_ims_test))):
#       4         with torch.no_grad():
# ----> 5             new_im = grid.render_large_image_from_rays(disp_rays_test[i], (N_points, 1.2))
#       6
#       7             m[i] = peak_signal_noise_ratio(new_im, disp_ims_test[i].astype('float32'))
#
# ~/MVA/Radiance-Fields/VoxelGrid.py in render_large_image_from_rays(self, im_rays, kwargs, batch_size)
#     217
# ...

# %%
plt.plot(range(0,33,2), psnr, label='4 SH coefficients')
plt.plot(range(0,33,2), psnr2, label='1 SH coefficients')
plt.xlabel('epoch')
plt.ylabel('psnr')

plt.legend()

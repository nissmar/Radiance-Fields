# %%
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.autograd import Variable
import pickle 
from ply import write_ply

from scipy.special import sph_harm

from utilities import *
from VoxelGrid import VoxelGrid, VoxelGridSpherical, VoxelGridSphericalInterp
import os


from skimage.metrics import peak_signal_noise_ratio

os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
device='cuda' if torch.cuda.is_available() else 'cpu'

N_points=200

dataset = "../nerf_synthetic/materials"

# %%
test_focal, test_c2w, test_gt = get_data(dataset, "test")
# Out:
# LOAD DATA ../nerf_synthetic/materials/test
# 100%|█████████████████████████████████████████| 200/200 [00:05<00:00, 33.55it/s]

# %%
red = 4
disp_ims_test, disp_rays_test = reduce_data(test_c2w, test_gt,test_focal, red)
disp_im_w = disp_ims_test[0].shape[0]

# %%
VG = VoxelGrid(2)
VG.load('materials64.obj')

# %%
VG2.save('materials64.obj')

# %%
new_im = VG2.render_large_image_from_rays(disp_rays_test[0], (N_points, 1.2))
plt.imshow(new_im)

# %%
N_points = 500
m = np.zeros(len(disp_ims_test))
for i in tqdm(range(len(disp_ims_test))):
    with torch.no_grad():
        new_im = VG2.render_large_image_from_rays(disp_rays_test[i], (N_points, 1.2))
        
        m[i] = peak_signal_noise_ratio(np.clip(new_im, 0,1), disp_ims_test[i].astype('float32'))
    
        print(m.sum()/(i+1))
# Out:
#   1%|▍                                          | 2/200 [00:00<00:27,  7.19it/s]
# 19.635542217200737
# 19.613643902466592
#   2%|▊                                          | 4/200 [00:00<00:25,  7.75it/s]
# 19.593262446759862
# 19.575129850756255
#   3%|█▎                                         | 6/200 [00:00<00:23,  8.10it/s]
# 19.55621314752911
# 19.53680638047654
#   4%|█▋                                         | 8/200 [00:01<00:23,  8.34it/s]
# 19.523935590795947
# 19.516718322867128
#   5%|██                                        | 10/200 [00:01<00:22,  8.46it/s]
# 19.51590643577827
# 19.520121780275435
#   6%|██▌                                       | 12/200 [00:01<00:21,  8.66it/s]
# 19.528521714524096
# 19.540821495289933
#   7%|██▉                                       | 14/200 [00:01<00:21,  8.77it/s]
# 19.55861766966046
# 19.581395505864638
#   8%|███▎                                      | 16/200 [00:01<00:20,  8.82it/s]
# 19.610144818179325
# 19.643743680016282
# ...

# %%
N_points = 500
m = np.zeros(len(disp_ims_test))
for i in tqdm(range(len(disp_ims_test))):
    with torch.no_grad():
        new_im = VG.render_large_image_from_rays(disp_rays_test[i], (N_points, 1.2))
        
        m[i] = peak_signal_noise_ratio(np.clip(new_im, 0,1), disp_ims_test[i].astype('float32'))
    
        print(m.sum()/(i+1))
# Out:
#   0%|▏                                          | 1/200 [00:00<03:07,  1.06it/s]
# 20.678437319340684
#   1%|▍                                          | 2/200 [00:01<03:06,  1.06it/s]
# 20.44855647663001
#   2%|▋                                          | 3/200 [00:02<03:05,  1.06it/s]
# 20.253943347237534
#   2%|▊                                          | 4/200 [00:03<03:04,  1.06it/s]
# 20.118667851412145
#   2%|█                                          | 5/200 [00:04<03:04,  1.06it/s]
# 20.038600491907108
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_8831/893715725.py in <module>
#       3 for i in tqdm(range(len(disp_ims_test))):
#       4     with torch.no_grad():
# ----> 5         new_im = VG.render_large_image_from_rays(disp_rays_test[i], (N_points, 1.2))
#       6
# ...

# %%
plt.imshow(disp_ims_test[0])

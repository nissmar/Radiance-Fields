# %%
import matplotlib.pyplot as plt 

from out import L1h30

# %%
plt.plot(L1h30)
plt.ylabel("Error")
plt.xlabel("Iterations")
# Out:
# Text(0.5, 0, 'Iterations')

# %%
L1h30[-1]
# Out:
# 0.023442063480615616
